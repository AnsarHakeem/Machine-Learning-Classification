# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_breast_cancer

# %%
data=load_breast_cancer()

# %%
x=data.data
y=data.target
feature_names=data.feature_names

# %%
df=pd.DataFrame(x,columns=feature_names)
df['target']=y

# %%
df.head(20)
# Out:
#     mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0         17.99         10.38          122.80     1001.0          0.11840
# 1         20.57         17.77          132.90     1326.0          0.08474
# 2         19.69         21.25          130.00     1203.0          0.10960
# 3         11.42         20.38           77.58      386.1          0.14250
# 4         20.29         14.34          135.10     1297.0          0.10030
# 5         12.45         15.70           82.57      477.1          0.12780
# 6         18.25         19.98          119.60     1040.0          0.09463
# 7         13.71         20.83           90.20      577.9          0.11890
# 8         13.00         21.82           87.50      519.8          0.12730
# 9         12.46         24.04           83.97      475.9          0.11860
# 10        16.02         23.24          102.70      797.8          0.08206
# 11        15.78         17.89          103.60      781.0          0.09710
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.isnull()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          False         False           False      False            False
# 1          False         False           False      False            False
# 2          False         False           False      False            False
# 3          False         False           False      False            False
# 4          False         False           False      False            False
# ..           ...           ...             ...        ...              ...
# 564        False         False           False      False            False
# 565        False         False           False      False            False
# 566        False         False           False      False            False
# 567        False         False           False      False            False
# 568        False         False           False      False            False
#
# ...

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 564    False
# 565    False
# 566    False
# 567    False
# 568    False
# Length: 569, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x)
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['mean radius'])
# Out:
# <Axes: xlabel='mean radius'>

# %% [markdown]
# Box plots are the best tool to know about the data in python. It shows median , quartiles and potential outliers.In boxplot we can clearly know about mean , 1st quartile , median , 3rd quartile , and maximum.

# %%
num_columns=df.select_dtypes(include='number')
num_columns
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
for i in num_columns.columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
def outliers(df):
    for col in df.select_dtypes(include=['int64', 'float64']).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        lower = Q1 - (1.5 * IQR)
        upper = Q3 + (1.5 * IQR)

        df[col] = df[col].apply(lambda x: lower if x < lower else upper if x > upper else x)

    return df

# %% [markdown]
# IQR method is using for identifyimg outliers and with trimmimng and capping we can remove outliers and make more cleaner data visualisation

# %%
df1=outliers(df)

# %%
for i in num_columns.columns:
    sns.boxplot(data=df1,x=i)
    plt.show()

# %%
df1.skew()
# Out:
# mean radius                0.655953
# mean texture               0.449700
# mean perimeter             0.701081
# mean area                  0.922884
# mean smoothness            0.257712
# mean compactness           0.826755
# mean concavity             1.023859
# mean concave points        1.004049
# mean symmetry              0.403621
# mean fractal dimension     0.682430
# radius error               1.025031
# texture error              0.740987
# perimeter error            1.034389
# area error                 1.130940
# smoothness error           0.780923
# compactness error          0.990285
# concavity error            0.916740
# concave points error       0.539571
# symmetry error             0.869297
# fractal dimension error    0.979344
# worst radius               0.849779
# worst texture              0.386858
# worst perimeter            0.874870
# worst area                 1.048970
# worst smoothness           0.247199
# worst compactness          0.915295
# ...

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer(method='yeo-johnson')

# %%
numerical_features = df1.select_dtypes(include=['float64', 'int64']).columns

# %%
df1[numerical_features] = pt.fit_transform(df1[numerical_features])

# %%
df1[numerical_features].skew()
# Out:
# mean radius                0.011115
# mean texture              -0.002533
# mean perimeter             0.010112
# mean area                  0.005457
# mean smoothness            0.006193
# mean compactness           0.102176
# mean concavity             0.210993
# mean concave points        0.194157
# mean symmetry              0.005121
# mean fractal dimension     0.049092
# radius error               0.157291
# texture error              0.021078
# perimeter error            0.070418
# area error                 0.056353
# smoothness error           0.075000
# compactness error          0.170630
# concavity error            0.102595
# concave points error       0.006558
# symmetry error             0.109069
# fractal dimension error    0.151253
# worst radius               0.034750
# worst texture             -0.008927
# worst perimeter            0.031901
# worst area                 0.024929
# worst smoothness           0.005460
# worst compactness          0.089849
# ...

# %%
df2=df1[numerical_features]

# %%
correlation=df2.corr()
correlation
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.321373        0.997968   0.999115
# mean texture                0.321373      1.000000        0.326242   0.324983
# mean perimeter              0.997968      0.326242        1.000000   0.996713
# mean area                   0.999115      0.324983        0.996713   1.000000
# mean smoothness             0.150890     -0.010100        0.187436   0.140765
# mean compactness            0.484556      0.242076        0.533605   0.476332
# mean concavity              0.652054      0.322642        0.690423   0.649699
# mean concave points         0.774812      0.288534        0.804306   0.771287
# mean symmetry               0.120061      0.088221        0.151189   0.114964
# mean fractal dimension     -0.371560     -0.072064       -0.323931  -0.379026
# radius error                0.582796      0.348875        0.592936   0.588160
# ...

# %%
plt.figure(figsize=(22,20))
sns.heatmap(correlation,annot=True,fmt='.2f',cmap='coolwarm')
plt.title('correlation of breast cancer')
# Out:
# Text(0.5, 1.0, 'correlation of breast cancer')

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
x=df2
y=df['target']

# %%
sk=SelectKBest(score_func=f_classif,k=15)
xnew=sk.fit_transform(x,y)

# %%
selected_features = x.columns[sk.get_support()]
feature_scores = pd.DataFrame({'Feature': x.columns, 'Score': sk.scores_}).sort_values(by='Score', ascending=False)

print("Selected Features:", selected_features)
print("\nFeature Scores:")
print(feature_scores)
# Out:
# Selected Features: Index(['mean radius', 'mean perimeter', 'mean area', 'mean compactness',
#        'mean concavity', 'mean concave points', 'radius error',
#        'perimeter error', 'area error', 'worst radius', 'worst perimeter',
#        'worst area', 'worst compactness', 'worst concavity',
#        'worst concave points'],
#       dtype='object')
#
# Feature Scores:
#                     Feature       Score
# 7       mean concave points  979.985907
# 22          worst perimeter  914.408374
# 23               worst area  886.559410
# 27     worst concave points  867.101698
# 20             worst radius  866.414171
# 6            mean concavity  717.592998
# 2            mean perimeter  679.260137
# 3                 mean area  642.004466
# 13               area error  624.107657
# 0               mean radius  623.817127
# 26          worst concavity  525.741746
# 12          perimeter error  382.985870
# 10             radius error  374.097181
# ...

# %% [markdown]
# Feature selection is used to remove irrelevant features that can affect the prediction

# %%
y.unique()
# Out:
# array([0, 1])

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
xscaled=scaler.fit_transform (x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(xscaled,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model1=LogisticRegression()

# %%
model1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model1.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy1=accuracy_score(y_test,y_pred)
accuracy1
# Out:
# 0.9824561403508771

# %%
cm1=confusion_matrix(y_test,y_pred)
cm1
# Out:
# array([[42,  1],
#        [ 1, 70]], dtype=int64)

# %%
plt.figure(figsize=(6,5))
sns.heatmap(cm1,annot=True,cmap="Greens")
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        43
#            1       0.99      0.99      0.99        71
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model2=DecisionTreeClassifier()

# %%
model2.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y.dt=model2.predict(x_test)

# %%
accuracy2=accuracy_score(y_test,y.dt)
accuracy2
# Out:
# 0.9473684210526315

# %%
cm2=confusion_matrix(y_test,y.dt)
cm2
# Out:
# array([[40,  3],
#        [ 3, 68]], dtype=int64)

# %%
plt.figure(figsize=(6,5))
sns.heatmap(cm2,annot=True,cmap="Oranges")
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y.dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        43
#            1       0.96      0.96      0.96        71
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model3=RandomForestClassifier()

# %%
model3.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y.rf=model3.predict(x_test)

# %%
accuracy3=accuracy_score(y_test,y.rf)
accuracy3
# Out:
# 0.9649122807017544

# %%
cm3=confusion_matrix(y_test,y.rf)
cm3
# Out:
# array([[40,  3],
#        [ 1, 70]], dtype=int64)

# %%
plt.figure(figsize=(6,5))
sns.heatmap(cm3,annot=True,cmap="Purples")
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y.rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95        43
#            1       0.96      0.99      0.97        71
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114

# %%
from sklearn.svm import SVC

# %%
model4=SVC()

# %%
model4.fit(x_train,y_train)
# Out:
# SVC()

# %%
y.svc=model4.predict(x_test)

# %%
accuracy4=accuracy_score(y_test,y.svc)
accuracy4
# Out:
# 0.9736842105263158

# %%
cm4=confusion_matrix(y_test,y.svc)
cm4
# Out:
# array([[41,  2],
#        [ 1, 70]], dtype=int64)

# %%
plt.figure(figsize=(6,5))
sns.heatmap(cm3,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y.svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96        43
#            1       0.97      0.99      0.98        71
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model5=KNeighborsClassifier()

# %%
model5.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y.knn=model5.predict(x_test)

# %%
accuracy5=accuracy_score(y_test,y.knn)
accuracy5
# Out:
# 0.956140350877193

# %%
cm5=confusion_matrix(y_test,y.knn)
cm5
# Out:
# array([[41,  2],
#        [ 3, 68]], dtype=int64)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(cm5,annot=True,cmap='Reds')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y.knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94        43
#            1       0.97      0.96      0.96        71
#
#     accuracy                           0.96       114
#    macro avg       0.95      0.96      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
model_performance = {
    'Logistic Regression': accuracy1,
    'Decision Tree Classifier': accuracy2,
    'Random Forest Classifier': accuracy3,
    'Support Vector Classifier': accuracy4,
    'k-NN Classifier': accuracy5
}

best_model = max(model_performance, key=model_performance.get)
print(f'The best model is: {best_model} with Accuracy: {model_performance[best_model]}')
# Out:
# The best model is: Logistic Regression with Accuracy: 0.9824561403508771
